# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, fbeta_score, make_scorer
import matplotlib.pyplot as plt
import sys
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import  cross_validate

# %%
sys.path.append('./drive/MyDrive/TFG/implementations/machine_learning_tfg/')

# %%
from src.utils.model_metrics_generator import ModelMetricsGenerator
from src.utils.cross_validation_utils import print_metrics
from src.utils.my_metrics import accuracy_precision_recall_specifity_f2_score

# %% [markdown]
# # Load data

# %%
input_data = pd.read_excel('/content/drive/MyDrive/TFG/implementations/machine_learning_tfg/data/prepared/prepared_ICU_Prediction.xlsx')
#input_data = pd.read_excel('./../data/prepared/prepared_ICU_Prediction.xlsx')
ground_truth = input_data['ICU']
sample_data = input_data.drop('ICU', axis=1)
train_data, test_data, train_truth, test_truth = train_test_split(sample_data, ground_truth, test_size=0.2, shuffle=True)

# %% [markdown]
# # Gaussian Naive Bayes

# %%
gnb_model = GaussianNB()
model_metrics_generator = ModelMetricsGenerator(test_truth)
model_metrics_generator.generate_metrics(gnb_model, train_data, train_truth, test_data)
model_metrics_generator.print_results()
# Out:
# Accuracy: 0.7636363636363637
# Precision: 0.7391304347826086
# Recall: 0.39080459770114945
# Specifity: 0.9361702127659575
# F2-score: 0.4314720812182741
# Fit time: 0.009043 seconds.
# Predict time: 0.002335 seconds.

# %%
gnb_model2 = GaussianNB()
metrics = accuracy_precision_recall_specifity_f2_score()
results = cross_validate(gnb_model2, sample_data, ground_truth, cv=3, scoring=metrics)
print_metrics(results)
# Out:
# fit_time mean value: 0.00621803601582845
# score_time mean value: 0.0066157182057698565
# test_accuracy mean value: 0.7667673167515504
# test_precision mean value: 0.7735957655506821
# test_recall mean value: 0.42324561403508776
# test_specifity mean value: 0.9377763491553269
# test_f2_score mean value: 0.46318505103182467
