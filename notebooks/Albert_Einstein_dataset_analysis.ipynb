# %%
import pandas as pd
import numpy as np

data = pd.read_excel('./../data/raw/Albert_Einstein_DataSet.xlsx')

# %% [markdown]
# #Quality dataset analysis

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data.shape
# Out:
# (5644, 111)

# %%
data.describe()
# Out:
#        Patient age quantile  Patient addmited to regular ward (1=yes, 0=no)  \
# count           5644.000000                                     5644.000000
# mean               9.318391                                        0.013997
# std                5.777903                                        0.117489
# min                0.000000                                        0.000000
# 25%                4.000000                                        0.000000
# 50%                9.000000                                        0.000000
# 75%               14.000000                                        0.000000
# max               19.000000                                        1.000000
#
#        Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# count                                        5644.000000
# mean                                            0.008859
# std                                             0.093713
# ...

# %% [markdown]
# Number of rows with null values

# %%
data.isnull().any(axis=1).sum()
# Out:
# 5644

# %% [markdown]
# Perentage of empty values.

# %%
(data.isnull().sum().sum()/np.product(data.shape)) * 100
# Out:
# 88.06003026414082

# %% [markdown]
# Number of empty columns.

# %%
data.isnull().all(axis=0).sum()
# Out:
# 5

# %% [markdown]
# We remove empty cols.

# %%
data.dropna(axis=1, how='all', inplace=True)

# %%
data.shape
# Out:
# (5644, 106)

# %% [markdown]
# Checking how many empty rows there are.

# %%
data.isnull().all(axis=0).sum()
# Out:
# 0

# %% [markdown]
# After removing empty cols, we only get a +-1% less of empty values.

# %%
(data.isnull().sum().sum()/np.product(data.shape)) * 100
# Out:
# 87.49682414452482

# %%
null_percentage = data.isnull().mean() *100
null_percentage[null_percentage >= 75].count()
# Out:
# 100
